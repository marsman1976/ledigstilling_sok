# %%
# imports
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
sns.set()
import numpy as np

# %%
df=pd.read_csv('ledigstillinglonn.csv',skiprows=1)
df.head()
# Out:
#      Month  ledig stilling: (Norway)  lønn: (Norway)
# 0  2004-01                         9              12
# 1  2004-02                        18              16
# 2  2004-03                        14              29
# 3  2004-04                         7              24
# 4  2004-05                        14              17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     240 non-null    object
#  1   ledig stilling: (Norway)  240 non-null    int64
#  2   lønn: (Norway)            240 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 5.8+ KB

# %%
df.columns=['Månad','ledig_stilling','Lønn']
df.head()
# Out:
#      Månad  ledig_stilling  Lønn
# 0  2004-01               9    12
# 1  2004-02              18    16
# 2  2004-03              14    29
# 3  2004-04               7    24
# 4  2004-05              14    17

# %%
df['Månad']=pd.to_datetime(df['Månad'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Månad           240 non-null    datetime64[ns]
#  1   ledig_stilling  240 non-null    int64
#  2   Lønn            240 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 5.8 KB

# %%
df.set_index('Månad',inplace=True)
df.head()
# Out:
#             ledig_stilling  Lønn
# Månad
# 2004-01-01               9    12
# 2004-02-01              18    16
# 2004-03-01              14    29
# 2004-04-01               7    24
# 2004-05-01              14    17

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Månad'>

# %%
df[['ledig_stilling']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Månad'>

# %%
df[['Lønn']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Månad'>

# %%
df[['ledig_stilling','Lønn']].rolling(12).mean().plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Månad'>

# %%
pd.concat([df[['ledig_stilling']].rolling(12).mean(),df[['Lønn']].rolling(12).mean()],axis=1).plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Månad'>
